# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
import tensorflow as tf
from tensorflow.keras.metrics import MeanIoU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model
from tqdm import tqdm
import random
import pickle
from tensorflow.keras.callbacks import Callback, ModelCheckpoint,  EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam
# Out:
# Segmentation Models: using `keras` framework.

# %%
sm.set_framework('tf.keras')

# %% [markdown]
# ## Data Loading and Manipulating:

# %%
# Making a function to load the data:
def data_loader(folder_dir):
    image_dataset = []
    for images in os.listdir(folder_dir):
        image = cv2.imread(folder_dir+'/'+images, 1)
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (128, 128))
        image = Image.fromarray(image)
        image = np.array(image)
        image_dataset.append(image)
    return image_dataset

# %%
image_dataset = data_loader('night_ride_dataset/Images/') # Normal Images

# %%
mask_dataset = data_loader('night_ride_dataset/Masked_Images/') # Masked Images

# %%
image_dataset = np.array(image_dataset)
mask_dataset = np.array(mask_dataset)

# %%
mask_dataset.shape
# Out:
# (200, 128, 128, 3)

# %%
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(mask_dataset[image_number])
plt.show()
# Just checking if data is loaded properly or not.

# %%
mask_labels = pd.read_csv('night_ride_dataset/class_dict.csv') # mask labels RGB values...

# %%
mask_labels
# Out:
#          name    r    g    b
# 0        bike   74  144  226
# 1       rider   65  117    6
# 2        road  155  155  155
# 3    lanemark  248  231   28
# 4     movable   57  234   92
# 5  undrivable  245  166   35

# %%
# converting 3 values (RGB) to 1 label values...
def rgb_to_labels(img, mask_labels):
    label_seg = np.zeros(img.shape,dtype=np.uint8)
    for i in range(mask_labels.shape[0]):
        label_seg[np.all(img == list(mask_labels.iloc[i, [1,2,3]]), axis=-1)] = i
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels...
    return label_seg

# %%
labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_labels(mask_dataset[i], mask_labels) # calling rgb to labels for each images...
    labels.append(label)

# %%
labels = np.array(labels)
labels = np.expand_dims(labels, axis=3) # adding channel dim...
print(np.unique(labels))
# Out:
# [0 1 2 3 4 5]

# %%
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()

# %%
n_classes = len(np.unique(labels)) # 7 Classes
labels_cat = to_categorical(labels, num_classes=n_classes) # one hot encoding the labels

# %%
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.25, random_state = 42)
# train test splitting.

# %% [markdown]
# ## Modelling:
# We are using resnet pre-trained model to set the initial weights of the UNet. Below is the architecture of the Resnet34:
# ![Resnet34.jpg](attachment:Resnet34.jpg)

# %%
BACKBONE = 'resnet34' 
preprocess_input = sm.get_preprocessing(BACKBONE)
# Using weights from pretrained resnet model

# %%
X_train_prepr = preprocess_input(X_train)
X_test_prepr = preprocess_input(X_test)

# %% [markdown]
# We are using UNet architecture to train our model for semantic segmentation, below is the architecture of UNet:
# ![UNet.png](attachment:UNet.png)

# %%
# defining model:
model_resnet_backbone = sm.Unet(BACKBONE, encoder_weights='imagenet', classes=n_classes, activation='softmax')

# %%
# accuracy as metrics, adam optimizer and loss function that needs to be optimized is categorical crossentropy as its a multiclass classification problem:
metrics=['accuracy']
model_resnet_backbone.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)

# %%
model_resnet_backbone.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, None, None,  0           []
#                                  3)]
#
#  bn_data (BatchNormalization)   (None, None, None,   9           ['data[0][0]']
#                                 3)
#
#  zero_padding2d_34 (ZeroPadding  (None, None, None,   0          ['bn_data[0][0]']
#  2D)                            3)
#
#  conv0 (Conv2D)                 (None, None, None,   9408        ['zero_padding2d_34[0][0]']
#                                 64)
#
#  bn0 (BatchNormalization)       (None, None, None,   256         ['conv0[0][0]']
#                                 64)
#
#  relu0 (Activation)             (None, None, None,   0           ['bn0[0][0]']
#                                 64)
#
#  zero_padding2d_35 (ZeroPadding  (None, None, None,   0          ['relu0[0][0]']
#  2D)                            64)
#
#  pooling0 (MaxPooling2D)        (None, None, None,   0           ['zero_padding2d_35[0][0]']
#                                 64)
#
#  stage1_unit1_bn1 (BatchNormali  (None, None, None,   256        ['pooling0[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu1 (Activation  (None, None, None,   0          ['stage1_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_36 (ZeroPadding  (None, None, None,   0          ['stage1_unit1_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit1_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_36[0][0]']
#                                 64)
#
#  stage1_unit1_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit1_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit1_relu2 (Activation  (None, None, None,   0          ['stage1_unit1_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_37 (ZeroPadding  (None, None, None,   0          ['stage1_unit1_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit1_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_37[0][0]']
#                                 64)
#
#  stage1_unit1_sc (Conv2D)       (None, None, None,   4096        ['stage1_unit1_relu1[0][0]']
#                                 64)
#
#  add_16 (Add)                   (None, None, None,   0           ['stage1_unit1_conv2[0][0]',
#                                 64)                               'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, None, None,   256        ['add_16[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu1 (Activation  (None, None, None,   0          ['stage1_unit2_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_38 (ZeroPadding  (None, None, None,   0          ['stage1_unit2_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit2_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_38[0][0]']
#                                 64)
#
#  stage1_unit2_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit2_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit2_relu2 (Activation  (None, None, None,   0          ['stage1_unit2_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_39 (ZeroPadding  (None, None, None,   0          ['stage1_unit2_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit2_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_39[0][0]']
#                                 64)
#
#  add_17 (Add)                   (None, None, None,   0           ['stage1_unit2_conv2[0][0]',
#                                 64)                               'add_16[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, None, None,   256        ['add_17[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu1 (Activation  (None, None, None,   0          ['stage1_unit3_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_40 (ZeroPadding  (None, None, None,   0          ['stage1_unit3_relu1[0][0]']
#  2D)                            64)
#
#  stage1_unit3_conv1 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_40[0][0]']
#                                 64)
#
#  stage1_unit3_bn2 (BatchNormali  (None, None, None,   256        ['stage1_unit3_conv1[0][0]']
#  zation)                        64)
#
#  stage1_unit3_relu2 (Activation  (None, None, None,   0          ['stage1_unit3_bn2[0][0]']
#  )                              64)
#
#  zero_padding2d_41 (ZeroPadding  (None, None, None,   0          ['stage1_unit3_relu2[0][0]']
#  2D)                            64)
#
#  stage1_unit3_conv2 (Conv2D)    (None, None, None,   36864       ['zero_padding2d_41[0][0]']
#                                 64)
#
#  add_18 (Add)                   (None, None, None,   0           ['stage1_unit3_conv2[0][0]',
#                                 64)                               'add_17[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, None, None,   256        ['add_18[0][0]']
#  zation)                        64)
#
#  stage2_unit1_relu1 (Activation  (None, None, None,   0          ['stage2_unit1_bn1[0][0]']
#  )                              64)
#
#  zero_padding2d_42 (ZeroPadding  (None, None, None,   0          ['stage2_unit1_relu1[0][0]']
#  2D)                            64)
#
#  stage2_unit1_conv1 (Conv2D)    (None, None, None,   73728       ['zero_padding2d_42[0][0]']
#                                 128)
#
#  stage2_unit1_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit1_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit1_relu2 (Activation  (None, None, None,   0          ['stage2_unit1_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_43 (ZeroPadding  (None, None, None,   0          ['stage2_unit1_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit1_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_43[0][0]']
#                                 128)
#
#  stage2_unit1_sc (Conv2D)       (None, None, None,   8192        ['stage2_unit1_relu1[0][0]']
#                                 128)
#
#  add_19 (Add)                   (None, None, None,   0           ['stage2_unit1_conv2[0][0]',
#                                 128)                              'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, None, None,   512        ['add_19[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu1 (Activation  (None, None, None,   0          ['stage2_unit2_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_44 (ZeroPadding  (None, None, None,   0          ['stage2_unit2_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit2_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_44[0][0]']
#                                 128)
#
#  stage2_unit2_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit2_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit2_relu2 (Activation  (None, None, None,   0          ['stage2_unit2_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_45 (ZeroPadding  (None, None, None,   0          ['stage2_unit2_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit2_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_45[0][0]']
#                                 128)
#
#  add_20 (Add)                   (None, None, None,   0           ['stage2_unit2_conv2[0][0]',
#                                 128)                              'add_19[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, None, None,   512        ['add_20[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu1 (Activation  (None, None, None,   0          ['stage2_unit3_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_46 (ZeroPadding  (None, None, None,   0          ['stage2_unit3_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit3_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_46[0][0]']
#                                 128)
#
#  stage2_unit3_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit3_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit3_relu2 (Activation  (None, None, None,   0          ['stage2_unit3_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_47 (ZeroPadding  (None, None, None,   0          ['stage2_unit3_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit3_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_47[0][0]']
#                                 128)
#
#  add_21 (Add)                   (None, None, None,   0           ['stage2_unit3_conv2[0][0]',
#                                 128)                              'add_20[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, None, None,   512        ['add_21[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu1 (Activation  (None, None, None,   0          ['stage2_unit4_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_48 (ZeroPadding  (None, None, None,   0          ['stage2_unit4_relu1[0][0]']
#  2D)                            128)
#
#  stage2_unit4_conv1 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_48[0][0]']
#                                 128)
#
#  stage2_unit4_bn2 (BatchNormali  (None, None, None,   512        ['stage2_unit4_conv1[0][0]']
#  zation)                        128)
#
#  stage2_unit4_relu2 (Activation  (None, None, None,   0          ['stage2_unit4_bn2[0][0]']
#  )                              128)
#
#  zero_padding2d_49 (ZeroPadding  (None, None, None,   0          ['stage2_unit4_relu2[0][0]']
#  2D)                            128)
#
#  stage2_unit4_conv2 (Conv2D)    (None, None, None,   147456      ['zero_padding2d_49[0][0]']
#                                 128)
#
#  add_22 (Add)                   (None, None, None,   0           ['stage2_unit4_conv2[0][0]',
#                                 128)                              'add_21[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, None, None,   512        ['add_22[0][0]']
#  zation)                        128)
#
#  stage3_unit1_relu1 (Activation  (None, None, None,   0          ['stage3_unit1_bn1[0][0]']
#  )                              128)
#
#  zero_padding2d_50 (ZeroPadding  (None, None, None,   0          ['stage3_unit1_relu1[0][0]']
#  2D)                            128)
#
#  stage3_unit1_conv1 (Conv2D)    (None, None, None,   294912      ['zero_padding2d_50[0][0]']
#                                 256)
#
#  stage3_unit1_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit1_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit1_relu2 (Activation  (None, None, None,   0          ['stage3_unit1_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_51 (ZeroPadding  (None, None, None,   0          ['stage3_unit1_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit1_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_51[0][0]']
#                                 256)
#
#  stage3_unit1_sc (Conv2D)       (None, None, None,   32768       ['stage3_unit1_relu1[0][0]']
#                                 256)
#  add_23 (Add)                   (None, None, None,   0           ['stage3_unit1_conv2[0][0]',
#                                 256)                              'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, None, None,   1024       ['add_23[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu1 (Activation  (None, None, None,   0          ['stage3_unit2_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_52 (ZeroPadding  (None, None, None,   0          ['stage3_unit2_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit2_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_52[0][0]']
#                                 256)
#
#  stage3_unit2_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit2_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit2_relu2 (Activation  (None, None, None,   0          ['stage3_unit2_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_53 (ZeroPadding  (None, None, None,   0          ['stage3_unit2_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit2_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_53[0][0]']
#                                 256)
#
#  add_24 (Add)                   (None, None, None,   0           ['stage3_unit2_conv2[0][0]',
#                                 256)                              'add_23[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, None, None,   1024       ['add_24[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu1 (Activation  (None, None, None,   0          ['stage3_unit3_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_54 (ZeroPadding  (None, None, None,   0          ['stage3_unit3_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit3_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_54[0][0]']
#                                 256)
#
#  stage3_unit3_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit3_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit3_relu2 (Activation  (None, None, None,   0          ['stage3_unit3_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_55 (ZeroPadding  (None, None, None,   0          ['stage3_unit3_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit3_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_55[0][0]']
#                                 256)
#
#  add_25 (Add)                   (None, None, None,   0           ['stage3_unit3_conv2[0][0]',
#                                 256)                              'add_24[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, None, None,   1024       ['add_25[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu1 (Activation  (None, None, None,   0          ['stage3_unit4_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_56 (ZeroPadding  (None, None, None,   0          ['stage3_unit4_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit4_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_56[0][0]']
#                                 256)
#
#  stage3_unit4_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit4_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit4_relu2 (Activation  (None, None, None,   0          ['stage3_unit4_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_57 (ZeroPadding  (None, None, None,   0          ['stage3_unit4_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit4_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_57[0][0]']
#                                 256)
#
#  add_26 (Add)                   (None, None, None,   0           ['stage3_unit4_conv2[0][0]',
#                                 256)                              'add_25[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, None, None,   1024       ['add_26[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu1 (Activation  (None, None, None,   0          ['stage3_unit5_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_58 (ZeroPadding  (None, None, None,   0          ['stage3_unit5_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit5_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_58[0][0]']
#                                 256)
#
#  stage3_unit5_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit5_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit5_relu2 (Activation  (None, None, None,   0          ['stage3_unit5_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_59 (ZeroPadding  (None, None, None,   0          ['stage3_unit5_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit5_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_59[0][0]']
#                                 256)
#
#  add_27 (Add)                   (None, None, None,   0           ['stage3_unit5_conv2[0][0]',
#                                 256)                              'add_26[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, None, None,   1024       ['add_27[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu1 (Activation  (None, None, None,   0          ['stage3_unit6_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_60 (ZeroPadding  (None, None, None,   0          ['stage3_unit6_relu1[0][0]']
#  2D)                            256)
#
#  stage3_unit6_conv1 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_60[0][0]']
#                                 256)
#
#  stage3_unit6_bn2 (BatchNormali  (None, None, None,   1024       ['stage3_unit6_conv1[0][0]']
#  zation)                        256)
#
#  stage3_unit6_relu2 (Activation  (None, None, None,   0          ['stage3_unit6_bn2[0][0]']
#  )                              256)
#
#  zero_padding2d_61 (ZeroPadding  (None, None, None,   0          ['stage3_unit6_relu2[0][0]']
#  2D)                            256)
#
#  stage3_unit6_conv2 (Conv2D)    (None, None, None,   589824      ['zero_padding2d_61[0][0]']
#                                 256)
#
#  add_28 (Add)                   (None, None, None,   0           ['stage3_unit6_conv2[0][0]',
#                                 256)                              'add_27[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, None, None,   1024       ['add_28[0][0]']
#  zation)                        256)
#
#  stage4_unit1_relu1 (Activation  (None, None, None,   0          ['stage4_unit1_bn1[0][0]']
#  )                              256)
#
#  zero_padding2d_62 (ZeroPadding  (None, None, None,   0          ['stage4_unit1_relu1[0][0]']
#  2D)                            256)
#
#  stage4_unit1_conv1 (Conv2D)    (None, None, None,   1179648     ['zero_padding2d_62[0][0]']
#                                 512)
#
#  stage4_unit1_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit1_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit1_relu2 (Activation  (None, None, None,   0          ['stage4_unit1_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_63 (ZeroPadding  (None, None, None,   0          ['stage4_unit1_relu2[0][0]']
#  2D)                            512)
#
#  stage4_unit1_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_63[0][0]']
#                                 512)
#
#  stage4_unit1_sc (Conv2D)       (None, None, None,   131072      ['stage4_unit1_relu1[0][0]']
#                                 512)
#
#  add_29 (Add)                   (None, None, None,   0           ['stage4_unit1_conv2[0][0]',
#                                 512)                              'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, None, None,   2048       ['add_29[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu1 (Activation  (None, None, None,   0          ['stage4_unit2_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_64 (ZeroPadding  (None, None, None,   0          ['stage4_unit2_relu1[0][0]']
#  2D)                            512)
#
#  stage4_unit2_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_64[0][0]']
#                                 512)
#
#  stage4_unit2_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit2_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit2_relu2 (Activation  (None, None, None,   0          ['stage4_unit2_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_65 (ZeroPadding  (None, None, None,   0          ['stage4_unit2_relu2[0][0]']
#  2D)                            512)
#
#  stage4_unit2_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_65[0][0]']
#                                 512)
#
#  add_30 (Add)                   (None, None, None,   0           ['stage4_unit2_conv2[0][0]',
#                                 512)                              'add_29[0][0]']
#
#  stage4_unit3_bn1 (BatchNormali  (None, None, None,   2048       ['add_30[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu1 (Activation  (None, None, None,   0          ['stage4_unit3_bn1[0][0]']
#  )                              512)
#
#  zero_padding2d_66 (ZeroPadding  (None, None, None,   0          ['stage4_unit3_relu1[0][0]']
#  2D)                            512)
#
#  stage4_unit3_conv1 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_66[0][0]']
#                                 512)
#
#  stage4_unit3_bn2 (BatchNormali  (None, None, None,   2048       ['stage4_unit3_conv1[0][0]']
#  zation)                        512)
#
#  stage4_unit3_relu2 (Activation  (None, None, None,   0          ['stage4_unit3_bn2[0][0]']
#  )                              512)
#
#  zero_padding2d_67 (ZeroPadding  (None, None, None,   0          ['stage4_unit3_relu2[0][0]']
#  2D)                            512)
#
#  stage4_unit3_conv2 (Conv2D)    (None, None, None,   2359296     ['zero_padding2d_67[0][0]']
#                                 512)
#
#  add_31 (Add)                   (None, None, None,   0           ['stage4_unit3_conv2[0][0]',
#                                 512)                              'add_30[0][0]']
#
#  bn1 (BatchNormalization)       (None, None, None,   2048        ['add_31[0][0]']
#                                 512)
#
#  relu1 (Activation)             (None, None, None,   0           ['bn1[0][0]']
#                                 512)
#
#  decoder_stage0_upsampling (UpS  (None, None, None,   0          ['relu1[0][0]']
#  ampling2D)                     512)
#
#  decoder_stage0_concat (Concate  (None, None, None,   0          ['decoder_stage0_upsampling[0][0]
#  nate)                          768)                             ',
#                                                                   'stage4_unit1_relu1[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, None, None,   1769472     ['decoder_stage0_concat[0][0]']
#                                 256)
#
#  decoder_stage0a_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0a_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0a_relu (Activati  (None, None, None,   0          ['decoder_stage0a_bn[0][0]']
#  on)                            256)
#
#  decoder_stage0b_conv (Conv2D)  (None, None, None,   589824      ['decoder_stage0a_relu[0][0]']
#                                 256)
#
#  decoder_stage0b_bn (BatchNorma  (None, None, None,   1024       ['decoder_stage0b_conv[0][0]']
#  lization)                      256)
#
#  decoder_stage0b_relu (Activati  (None, None, None,   0          ['decoder_stage0b_bn[0][0]']
#  on)                            256)
#
#  decoder_stage1_upsampling (UpS  (None, None, None,   0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)                     256)
#
#  decoder_stage1_concat (Concate  (None, None, None,   0          ['decoder_stage1_upsampling[0][0]
#  nate)                          384)                             ',
#                                                                   'stage3_unit1_relu1[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, None, None,   442368      ['decoder_stage1_concat[0][0]']
#                                 128)
#
#  decoder_stage1a_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1a_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1a_relu (Activati  (None, None, None,   0          ['decoder_stage1a_bn[0][0]']
#  on)                            128)
#
#  decoder_stage1b_conv (Conv2D)  (None, None, None,   147456      ['decoder_stage1a_relu[0][0]']
#                                 128)
#
#  decoder_stage1b_bn (BatchNorma  (None, None, None,   512        ['decoder_stage1b_conv[0][0]']
#  lization)                      128)
#
#  decoder_stage1b_relu (Activati  (None, None, None,   0          ['decoder_stage1b_bn[0][0]']
#  on)                            128)
#
#  decoder_stage2_upsampling (UpS  (None, None, None,   0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)                     128)
#
#  decoder_stage2_concat (Concate  (None, None, None,   0          ['decoder_stage2_upsampling[0][0]
#  nate)                          192)                             ',
#                                                                   'stage2_unit1_relu1[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, None, None,   110592      ['decoder_stage2_concat[0][0]']
#                                 64)
#
#  decoder_stage2a_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2a_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2a_relu (Activati  (None, None, None,   0          ['decoder_stage2a_bn[0][0]']
#  on)                            64)
#
#  decoder_stage2b_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage2a_relu[0][0]']
#                                 64)
#
#  decoder_stage2b_bn (BatchNorma  (None, None, None,   256        ['decoder_stage2b_conv[0][0]']
#  lization)                      64)
#
#  decoder_stage2b_relu (Activati  (None, None, None,   0          ['decoder_stage2b_bn[0][0]']
#  on)                            64)
#
#  decoder_stage3_upsampling (UpS  (None, None, None,   0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     64)
#
#  decoder_stage3_concat (Concate  (None, None, None,   0          ['decoder_stage3_upsampling[0][0]
#  nate)                          128)                             ',
#                                                                   'relu0[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, None, None,   36864       ['decoder_stage3_concat[0][0]']
#                                 32)
#
#  decoder_stage3a_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3a_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3a_relu (Activati  (None, None, None,   0          ['decoder_stage3a_bn[0][0]']
#  on)                            32)
#
#  decoder_stage3b_conv (Conv2D)  (None, None, None,   9216        ['decoder_stage3a_relu[0][0]']
#                                 32)
#
#  decoder_stage3b_bn (BatchNorma  (None, None, None,   128        ['decoder_stage3b_conv[0][0]']
#  lization)                      32)
#
#  decoder_stage3b_relu (Activati  (None, None, None,   0          ['decoder_stage3b_bn[0][0]']
#  on)                            32)
#
#  decoder_stage4_upsampling (UpS  (None, None, None,   0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     32)
#
#  decoder_stage4a_conv (Conv2D)  (None, None, None,   4608        ['decoder_stage4_upsampling[0][0]
#                                 16)                              ']
#
#  decoder_stage4a_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4a_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4a_relu (Activati  (None, None, None,   0          ['decoder_stage4a_bn[0][0]']
#  on)                            16)
#
#  decoder_stage4b_conv (Conv2D)  (None, None, None,   2304        ['decoder_stage4a_relu[0][0]']
#                                 16)
#
#  decoder_stage4b_bn (BatchNorma  (None, None, None,   64         ['decoder_stage4b_conv[0][0]']
#  lization)                      16)
#
#  decoder_stage4b_relu (Activati  (None, None, None,   0          ['decoder_stage4b_bn[0][0]']
#  on)                            16)
#
#  final_conv (Conv2D)            (None, None, None,   870         ['decoder_stage4b_relu[0][0]']
#                                 6)
#
#  softmax (Activation)           (None, None, None,   0           ['final_conv[0][0]']
#                                 6)
#
# ==================================================================================================
# Total params: 24,456,879
# Trainable params: 24,439,529
# Non-trainable params: 17,350
# __________________________________________________________________________________________________

# %%
# training the model for 100 epochs with batch size of 16:
history = model_resnet_backbone.fit(X_train_prepr, 
          y_train,
          batch_size=16, 
          epochs=100,
          verbose=1,
          validation_data=(X_test_prepr, y_test))
# Out:
# Epoch 1/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.3956 - accuracy: 0.8649 - val_loss: 1.4989 - val_accuracy: 0.6094
# Epoch 2/100
# 10/10 [==============================] - 34s 3s/step - loss: 0.3607 - accuracy: 0.8836 - val_loss: 1.3426 - val_accuracy: 0.6293
# Epoch 3/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.3253 - accuracy: 0.8963 - val_loss: 1.1118 - val_accuracy: 0.6647
# Epoch 4/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.3069 - accuracy: 0.9014 - val_loss: 0.8417 - val_accuracy: 0.7282
# Epoch 5/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2829 - accuracy: 0.9077 - val_loss: 0.8915 - val_accuracy: 0.6918
# Epoch 6/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.2570 - accuracy: 0.9173 - val_loss: 0.7989 - val_accuracy: 0.7180
# Epoch 7/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2395 - accuracy: 0.9222 - val_loss: 0.7596 - val_accuracy: 0.7275
# Epoch 8/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.2255 - accuracy: 0.9265 - val_loss: 0.5568 - val_accuracy: 0.8116
# Epoch 9/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2180 - accuracy: 0.9276 - val_loss: 0.5312 - val_accuracy: 0.8200
# Epoch 10/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.2381 - accuracy: 0.9193 - val_loss: 0.7223 - val_accuracy: 0.7357
# Epoch 11/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.2137 - accuracy: 0.9290 - val_loss: 0.5038 - val_accuracy: 0.8223
# Epoch 12/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1993 - accuracy: 0.9331 - val_loss: 0.5552 - val_accuracy: 0.8057
# Epoch 13/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.1901 - accuracy: 0.9357 - val_loss: 0.5053 - val_accuracy: 0.8251
# Epoch 14/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1822 - accuracy: 0.9377 - val_loss: 0.4276 - val_accuracy: 0.8572
# Epoch 15/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1808 - accuracy: 0.9379 - val_loss: 0.4087 - val_accuracy: 0.8673
# Epoch 16/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.1797 - accuracy: 0.9381 - val_loss: 0.3724 - val_accuracy: 0.8755
# Epoch 17/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1795 - accuracy: 0.9376 - val_loss: 0.3482 - val_accuracy: 0.8854
# Epoch 18/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1751 - accuracy: 0.9396 - val_loss: 0.4421 - val_accuracy: 0.8555
# Epoch 19/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1579 - accuracy: 0.9458 - val_loss: 0.3694 - val_accuracy: 0.8797
# Epoch 20/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1559 - accuracy: 0.9463 - val_loss: 0.3381 - val_accuracy: 0.8904
# Epoch 21/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1536 - accuracy: 0.9470 - val_loss: 0.3738 - val_accuracy: 0.8756
# Epoch 22/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1496 - accuracy: 0.9485 - val_loss: 0.3506 - val_accuracy: 0.8852
# Epoch 23/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1462 - accuracy: 0.9496 - val_loss: 0.3479 - val_accuracy: 0.8885
# Epoch 24/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1351 - accuracy: 0.9535 - val_loss: 0.3364 - val_accuracy: 0.8910
# Epoch 25/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1289 - accuracy: 0.9555 - val_loss: 0.3261 - val_accuracy: 0.8976
# Epoch 26/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1411 - accuracy: 0.9514 - val_loss: 0.3986 - val_accuracy: 0.8720
# Epoch 27/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1500 - accuracy: 0.9481 - val_loss: 0.5276 - val_accuracy: 0.8341
# Epoch 28/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1509 - accuracy: 0.9476 - val_loss: 0.4307 - val_accuracy: 0.8680
# Epoch 29/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1452 - accuracy: 0.9494 - val_loss: 0.5090 - val_accuracy: 0.8443
# Epoch 30/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1375 - accuracy: 0.9522 - val_loss: 0.4208 - val_accuracy: 0.8652
# Epoch 31/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1284 - accuracy: 0.9553 - val_loss: 0.3688 - val_accuracy: 0.8826
# Epoch 32/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1292 - accuracy: 0.9548 - val_loss: 0.3417 - val_accuracy: 0.8927
# Epoch 33/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1210 - accuracy: 0.9576 - val_loss: 0.3477 - val_accuracy: 0.8875
# Epoch 34/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1126 - accuracy: 0.9609 - val_loss: 0.3238 - val_accuracy: 0.8977
# Epoch 35/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1089 - accuracy: 0.9622 - val_loss: 0.3218 - val_accuracy: 0.9025
# Epoch 36/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1082 - accuracy: 0.9622 - val_loss: 0.3394 - val_accuracy: 0.9007
# Epoch 37/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1055 - accuracy: 0.9634 - val_loss: 0.3377 - val_accuracy: 0.9023
# Epoch 38/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1038 - accuracy: 0.9636 - val_loss: 0.3420 - val_accuracy: 0.9047
# Epoch 39/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1005 - accuracy: 0.9648 - val_loss: 0.3245 - val_accuracy: 0.9060
# Epoch 40/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.1019 - accuracy: 0.9642 - val_loss: 0.3356 - val_accuracy: 0.9047
# Epoch 41/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0956 - accuracy: 0.9667 - val_loss: 0.3384 - val_accuracy: 0.9067
# Epoch 42/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0943 - accuracy: 0.9671 - val_loss: 0.3280 - val_accuracy: 0.9070
# Epoch 43/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0926 - accuracy: 0.9676 - val_loss: 0.3382 - val_accuracy: 0.9060
# Epoch 44/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0931 - accuracy: 0.9670 - val_loss: 0.3226 - val_accuracy: 0.9083
# Epoch 45/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0907 - accuracy: 0.9683 - val_loss: 0.3382 - val_accuracy: 0.9057
# Epoch 46/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0885 - accuracy: 0.9689 - val_loss: 0.3370 - val_accuracy: 0.9081
# Epoch 47/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0903 - accuracy: 0.9680 - val_loss: 0.3397 - val_accuracy: 0.9050
# Epoch 48/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0885 - accuracy: 0.9687 - val_loss: 0.3509 - val_accuracy: 0.9057
# Epoch 49/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0893 - accuracy: 0.9687 - val_loss: 0.3467 - val_accuracy: 0.9063
# Epoch 50/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0934 - accuracy: 0.9667 - val_loss: 0.3620 - val_accuracy: 0.9062
# Epoch 51/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0905 - accuracy: 0.9679 - val_loss: 0.3547 - val_accuracy: 0.9092
# Epoch 52/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0863 - accuracy: 0.9694 - val_loss: 0.3465 - val_accuracy: 0.9111
# Epoch 53/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0824 - accuracy: 0.9707 - val_loss: 0.3443 - val_accuracy: 0.9115
# Epoch 54/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0826 - accuracy: 0.9709 - val_loss: 0.3555 - val_accuracy: 0.9094
# Epoch 55/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0829 - accuracy: 0.9706 - val_loss: 0.3530 - val_accuracy: 0.9101
# Epoch 56/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0811 - accuracy: 0.9712 - val_loss: 0.3497 - val_accuracy: 0.9082
# Epoch 57/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0780 - accuracy: 0.9725 - val_loss: 0.3488 - val_accuracy: 0.9115
# Epoch 58/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0755 - accuracy: 0.9735 - val_loss: 0.3549 - val_accuracy: 0.9098
# Epoch 59/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0748 - accuracy: 0.9736 - val_loss: 0.3599 - val_accuracy: 0.9083
# Epoch 60/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0749 - accuracy: 0.9735 - val_loss: 0.3496 - val_accuracy: 0.9114
# Epoch 61/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0755 - accuracy: 0.9732 - val_loss: 0.3637 - val_accuracy: 0.9087
# Epoch 62/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0734 - accuracy: 0.9741 - val_loss: 0.3686 - val_accuracy: 0.9113
# Epoch 63/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0775 - accuracy: 0.9722 - val_loss: 0.3597 - val_accuracy: 0.9106
# Epoch 64/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0743 - accuracy: 0.9737 - val_loss: 0.3734 - val_accuracy: 0.9106
# Epoch 65/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0724 - accuracy: 0.9744 - val_loss: 0.3712 - val_accuracy: 0.9111
# Epoch 66/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0702 - accuracy: 0.9751 - val_loss: 0.3867 - val_accuracy: 0.9102
# Epoch 67/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0679 - accuracy: 0.9760 - val_loss: 0.3784 - val_accuracy: 0.9097
# Epoch 68/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0673 - accuracy: 0.9762 - val_loss: 0.3650 - val_accuracy: 0.9107
# Epoch 69/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0665 - accuracy: 0.9765 - val_loss: 0.3747 - val_accuracy: 0.9094
# Epoch 70/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0677 - accuracy: 0.9759 - val_loss: 0.3748 - val_accuracy: 0.9096
# Epoch 71/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0678 - accuracy: 0.9760 - val_loss: 0.3762 - val_accuracy: 0.9105
# Epoch 72/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0695 - accuracy: 0.9750 - val_loss: 0.3877 - val_accuracy: 0.9102
# Epoch 73/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0675 - accuracy: 0.9759 - val_loss: 0.3924 - val_accuracy: 0.9108
# Epoch 74/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0679 - accuracy: 0.9757 - val_loss: 0.4101 - val_accuracy: 0.9096
# Epoch 75/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0655 - accuracy: 0.9766 - val_loss: 0.3916 - val_accuracy: 0.9101
# Epoch 76/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0634 - accuracy: 0.9775 - val_loss: 0.3917 - val_accuracy: 0.9108
# Epoch 77/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0623 - accuracy: 0.9778 - val_loss: 0.3968 - val_accuracy: 0.9110
# Epoch 78/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0620 - accuracy: 0.9780 - val_loss: 0.4085 - val_accuracy: 0.9104
# Epoch 79/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0618 - accuracy: 0.9780 - val_loss: 0.3859 - val_accuracy: 0.9097
# Epoch 80/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0606 - accuracy: 0.9784 - val_loss: 0.3986 - val_accuracy: 0.9107
# Epoch 81/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0608 - accuracy: 0.9783 - val_loss: 0.4037 - val_accuracy: 0.9103
# Epoch 82/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0604 - accuracy: 0.9782 - val_loss: 0.4172 - val_accuracy: 0.9100
# Epoch 83/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0596 - accuracy: 0.9787 - val_loss: 0.4115 - val_accuracy: 0.9119
# Epoch 84/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0617 - accuracy: 0.9780 - val_loss: 0.4142 - val_accuracy: 0.9086
# Epoch 85/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0614 - accuracy: 0.9781 - val_loss: 0.4153 - val_accuracy: 0.9088
# Epoch 86/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0602 - accuracy: 0.9786 - val_loss: 0.4143 - val_accuracy: 0.9088
# Epoch 87/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0573 - accuracy: 0.9796 - val_loss: 0.3974 - val_accuracy: 0.9118
# Epoch 88/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0555 - accuracy: 0.9803 - val_loss: 0.4057 - val_accuracy: 0.9103
# Epoch 89/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0554 - accuracy: 0.9804 - val_loss: 0.4176 - val_accuracy: 0.9108
# Epoch 90/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0546 - accuracy: 0.9805 - val_loss: 0.4167 - val_accuracy: 0.9106
# Epoch 91/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0543 - accuracy: 0.9806 - val_loss: 0.4186 - val_accuracy: 0.9123
# Epoch 92/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0533 - accuracy: 0.9812 - val_loss: 0.4096 - val_accuracy: 0.9123
# Epoch 93/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0534 - accuracy: 0.9810 - val_loss: 0.4292 - val_accuracy: 0.9085
# Epoch 94/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0534 - accuracy: 0.9809 - val_loss: 0.4355 - val_accuracy: 0.9111
# Epoch 95/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0526 - accuracy: 0.9813 - val_loss: 0.4461 - val_accuracy: 0.9088
# Epoch 96/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0546 - accuracy: 0.9803 - val_loss: 0.4532 - val_accuracy: 0.9067
# Epoch 97/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0549 - accuracy: 0.9803 - val_loss: 0.4379 - val_accuracy: 0.9081
# Epoch 98/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0538 - accuracy: 0.9806 - val_loss: 0.4560 - val_accuracy: 0.9088
# Epoch 99/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0509 - accuracy: 0.9818 - val_loss: 0.4458 - val_accuracy: 0.9085
# Epoch 100/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0513 - accuracy: 0.9817 - val_loss: 0.4395 - val_accuracy: 0.9106

# %% [markdown]
# ## Testing:

# %%
# plotting train and val accuracy:
history = history
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'y', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Saving the Model:

# %%
model_resnet_backbone.save('models/resnet_backbone.hdf5')

# %%
# Loading our saved model:
model = load_model('models/resnet_backbone.hdf5')

# %%
# making predictions:
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)
# Out:
# 2/2 [==============================] - 2s 521ms/step

# %%
# randomly selecting an image from the test set and making prediction...
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]
# Out:
# 1/1 [==============================] - 0s 69ms/step

# %%
# plotting the real image, test labeled image and predicted labeled image...
plt.figure(figsize=(16, 12))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()
